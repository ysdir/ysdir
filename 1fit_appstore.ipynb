# %%
import pandas as pd
import numpy as np
import json

from app_store_scraper import AppStore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6952\4222183297.py in <module>
#       3 import json
#       4
# ----> 5 from app_store_scraper import AppStore
#
# ModuleNotFoundError: No module named 'app_store_scraper'

# %%
onefit = AppStore(country='ru', app_name='1Fit', app_id = '1375903148')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6952\1860383523.py in <module>
# ----> 1 onefit = AppStore(country='ru', app_name='1Fit', app_id = '1375903148')
#
# NameError: name 'AppStore' is not defined

# %%
onefit.review(how_many = 10000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6952\3870055386.py in <module>
# ----> 1 onefit.review(how_many = 10000)
#
# NameError: name 'onefit' is not defined

# %%
onefit_reviews
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6952\1109761508.py in <module>
# ----> 1 onefit_reviews
#
# NameError: name 'onefit_reviews' is not defined

# %%
df = pd.DataFrame(data = onefit.reviews)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6952\1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.to_pickle('reviews_apple.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6952\815176710.py in <module>
# ----> 1 df.to_pickle('reviews_apple.pkl')
#
# NameError: name 'df' is not defined

# %%
pd.read_pickle('reviews_apple.pkl')
# Out:
#                   date                                             review  \
# 0  2018-08-20 19:53:03                               Отличное приложение)
# 1  2021-11-19 07:55:13  1FIT это самое лучшее приложение что могло бы ...
# 2  2022-01-24 19:42:07                        Еще не ходил не знаю почему
# 3  2018-07-12 06:06:16  Самое крутое , что могли придумать за последни...
# 4  2022-12-19 17:36:08  Обновленное приложение гораздо удобнее старого...
# 5  2022-07-14 15:29:02  Все хорошо разработчики красавцы\nТолько занят...
# 6  2022-12-13 05:08:56  Очень жаль, что в приложении нет пробного пери...
# 7  2022-12-09 08:29:23  Хотели приобрести абонемент на месяц - срок пр...
# 8  2022-11-10 05:02:49  Расписание занятий отображается, удобнее, но в...
# 9  2022-11-04 16:28:54  Бесполезное приложение. Просит сразу разрешени...
# 10 2022-11-01 20:19:43  1. Записавшись на тренировку через данное прил...
# 11 2022-10-25 13:53:32  Скачал приложение, хотел посмотреть цены и воз...
# ...

# %%
s
