# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews_all
reviews = reviews_all(
    'com.codebusters.onefit',
    sleep_milliseconds=0, # defaults to 0
    lang='ru', # defaults to 'en'
    country='kz', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
from google_play_scraper import Sort, reviews_all
reviews_kz = reviews_all(
    'com.codebusters.onefit',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='kz', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df1 = pd.DataFrame(data = reviews_kz)

# %%
df1.shape
# Out:
# (97, 10)

# %%
df1.head()
# Out:
#                                reviewId              userName  \
# 0  136bb8c2-4dbb-4992-98f3-1b803c41342c  Sabokhat Kalandarova
# 1  b26e0f3f-e4de-44e3-85c7-2c26dfbed2c4    Рахимхон Абдуллаев
# 2  784e0e61-1823-4f30-b743-65825c6fad25        Asad Sagidulla
# 3  13bd725e-64a7-4745-ab6e-18127b7232e7       Aziza Narziyeva
# 4  c1e37aa5-0664-4c0e-ac73-bdd96a11f035    Bahodir Abdulxayev
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AEdFTp...
# 1  https://play-lh.googleusercontent.com/a-/AD5-W...
# 2  https://play-lh.googleusercontent.com/a/AEdFTp...
# 3  https://play-lh.googleusercontent.com/a/AEdFTp...
# 4  https://play-lh.googleusercontent.com/a-/AD5-W...
#
#                                              content  score  thumbsUpCount  \
# 0  The application got worse with the recent upda...      1              2
# 1  The app itself is a bright and fresh idea, but...      2              1
# ...

# %%
len(reviews)
# Out:
# 1149

# %%
df.content[18]
# Out:
# 'Сама программа 1 фит супер ,но приложение после обновления отвратительное. Ничего не найти нормально,не понятно как записаться и где посмотреть отзывы,лучше бы оставили прошлую версию.'

# %%
df = pd.DataFrame(data=reviews)

# %%
df.shape
# Out:
# (1149, 10)

# %%
df.head()
# Out:
#                                reviewId              userName  \
# 0  063c39d5-6d3f-4c65-b6d6-c3ff2365d1b9      Aigerim Sakhieva
# 1  cde12588-9145-4641-87d8-2e211febc545            Eco Empath
# 2  8c0991f8-2c4b-46bb-b40c-87cf4732d1d4    Asylbek Satbaldiev
# 3  7eea173a-6c45-4b05-b29e-1e74c524e6dd  Ильшат Худайбергенов
# 4  e67ca477-451a-467b-85aa-52c5da4cae0b     Aizhan Karyspaeva
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AEdFTp...
# 1  https://play-lh.googleusercontent.com/a/AEdFTp...
# 2  https://play-lh.googleusercontent.com/a-/AD5-W...
# 3  https://play-lh.googleusercontent.com/a/AEdFTp...
# 4  https://play-lh.googleusercontent.com/a/AEdFTp...
#
#                                              content  score  thumbsUpCount  \
# 0  После обновления ужасно неудобно. Раньше откры...      4              1
# 1  Супер тема, спасибо большое разработчикам и кт...      5             14
# ...

# %%
df.score.value_counts()
# Out:
# 5    582
# 1    363
# 3     73
# 4     67
# 2     64
# Name: score, dtype: int64

# %%
result = df.merge(df1, how='outer')

# %%
result
# Out:
# C:\Users\Yerassyl\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\Yerassyl\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#                                   reviewId              userName language  \
# 0     063c39d5-6d3f-4c65-b6d6-c3ff2365d1b9      Aigerim Sakhieva     True
# 1     cde12588-9145-4641-87d8-2e211febc545            Eco Empath     True
# 2     8c0991f8-2c4b-46bb-b40c-87cf4732d1d4    Asylbek Satbaldiev     True
# 3     7eea173a-6c45-4b05-b29e-1e74c524e6dd  Ильшат Худайбергенов     True
# ...

# %%
result.to_pickle('reviews_google.pkl')

# %%
pd.read_pickle('reviews_google.pkl')
# Out:
# C:\Users\Yerassyl\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\Yerassyl\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#                                   reviewId              userName language  \
# 0     063c39d5-6d3f-4c65-b6d6-c3ff2365d1b9      Aigerim Sakhieva     True
# 1     cde12588-9145-4641-87d8-2e211febc545            Eco Empath     True
# 2     8c0991f8-2c4b-46bb-b40c-87cf4732d1d4    Asylbek Satbaldiev     True
# 3     7eea173a-6c45-4b05-b29e-1e74c524e6dd  Ильшат Худайбергенов     True
# ...

# %%
df['lanuguage'] = 'ru'

# %%
df1['lanuguage'] = 'en'

# %%
df1
# Out:
#                                 reviewId              userName  \
# 0   136bb8c2-4dbb-4992-98f3-1b803c41342c  Sabokhat Kalandarova
# 1   b26e0f3f-e4de-44e3-85c7-2c26dfbed2c4    Рахимхон Абдуллаев
# 2   784e0e61-1823-4f30-b743-65825c6fad25        Asad Sagidulla
# 3   13bd725e-64a7-4745-ab6e-18127b7232e7       Aziza Narziyeva
# 4   c1e37aa5-0664-4c0e-ac73-bdd96a11f035    Bahodir Abdulxayev
# ..                                   ...                   ...
# 92  d81e6705-a787-4dc9-a297-ad218ca0374f             sky angel
# 93  1981edf9-faad-46d6-8220-7cbead034b81     ASIK Nurmukhambet
# 94  fafd5b97-3424-463a-bcf8-e969683514da       Yelaman Apushev
# 95  28046677-f32b-4cdb-b2a4-824ae672e65c                 Maria
# 96  96bd9b0d-1336-4fc4-8810-7e3a1677bed6    Daniyar Kerimkulov
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a/AEdFTp...
# 1   https://play-lh.googleusercontent.com/a-/AD5-W...
# ...

# %%
df
# Out:
#                                   reviewId              userName  language  \
# 0     063c39d5-6d3f-4c65-b6d6-c3ff2365d1b9      Aigerim Sakhieva      True
# 1     cde12588-9145-4641-87d8-2e211febc545            Eco Empath      True
# 2     8c0991f8-2c4b-46bb-b40c-87cf4732d1d4    Asylbek Satbaldiev      True
# 3     7eea173a-6c45-4b05-b29e-1e74c524e6dd  Ильшат Худайбергенов      True
# 4     e67ca477-451a-467b-85aa-52c5da4cae0b     Aizhan Karyspaeva      True
# ...                                    ...                   ...       ...
# 1144  9bf7ef0b-6607-4fb0-90d7-b7d9291acf14     Бахтияр Темырбаев      True
# 1145  c2771251-0447-4c4a-91e1-0facdeb1fc61           серик мусин      True
# 1146  1c471e1d-e500-4838-afc8-aadf723f0a53          Аят Толеутай      True
# 1147  a09bb97e-40ea-4d4f-b8d9-94bf69436c8c    Нурганат Талдыбаев      True
# 1148  9a67686d-55be-4f5c-adae-f7a546837d0f      Жанасыл Асильбек      True
#
#                                               userImage  \
# ...
